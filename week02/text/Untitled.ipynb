# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from sklearn.externals import joblib
from my_measures import BinaryClassificationPerformance
# %matplotlib inline

# %%
amazon = pd.read_csv('AmazonReview.csv')
print(amazon.shape)
# Out:
# (5000, 9)

# %%
from sklearn.model_selection import train_test_split
raw_data_train, raw_data_test, y_labeled, y_labeled = train_test_split(amazon, amazon['helpful'], test_size = 0.3, random_state=378)
